# %% [markdown]
# # Experimento B1: entorno estocástico simple

# %% [markdown]
# ### Carga de librerías

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

import entorno
import agentes
import train

# %% [markdown]
# ### Parámetros de gráficos

# %%
plt.rcParams.update({
    'axes.titlesize': 40,     # Title size
    'axes.labelsize': 36,     # X and Y label size
    'xtick.labelsize': 28,    # X tick size
    'ytick.labelsize': 28,    # Y tick size
    'legend.fontsize': 32,    # Legend text size
    'figure.titlesize': 44    # Suptitle size
})

# %% [markdown]
# ### Parámetros del entorno

# %%
TAMANOS = {
    'n_estaciones': 4,
    'anclas_por_est': 10,
    'bicis_por_est': 5,    # Estado inicial
    'bicis_por_accion': 2  # Bicis movidas por el agente en c/ accion
}
COSTOS = {
    'accion': 1,
    'accion_invalida': 10,
    'est_vacia': 1,
    'est_llena': 1,
}
TIEMPOS = {
    'viaje': 10,
    'accion': 5,
    'episodio': 8*60,
    'estado': 1,
    'update': 999
}
PROBS = {
    'origen': 4*[0.1],
    'destino': np.array(4*[4*[0.25]])
}

# %% [markdown]
# ### Entrenar agente con $\varepsilon = 0,1$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.1,
    'alpha_step': 1,
    'alpha_end':  0.1,

    'eps_init': 0.1,
    'eps_step': 1,
    'eps_end':  0.1
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 16.9 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 7.9 ± 4.0 (4.1 ± 2.0%)
# # Prolongados: 0.7 ± 1.2 (0.4 ± 0.7%)
# Tiempo desbalanceo: 103.0 ± 36.3 (5.4 ± 1.9%)
# Recompensa: -30.0 ± 15.5
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 8.7 ± 4.3 (4.5 ± 2.2%)
# # Prolongados: 0.8 ± 1.3 (0.4 ± 0.7%)
# Tiempo desbalanceo: 110.2 ± 38.5 (5.7 ± 2.0%)
# Recompensa: -29.1 ± 12.7

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\varepsilon = 0,3$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.1,
    'alpha_step': 1,
    'alpha_end':  0.1,

    'eps_init': 0.3,
    'eps_step': 1,
    'eps_end':  0.3
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 15.9 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 7.8 ± 3.8 (4.0 ± 1.9%)
# # Prolongados: 0.4 ± 0.8 (0.2 ± 0.5%)
# Tiempo desbalanceo: 99.0 ± 31.7 (5.2 ± 1.6%)
# Recompensa: -22.6 ± 9.1
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 7.1 ± 3.7 (3.7 ± 1.9%)
# # Prolongados: 0.4 ± 0.7 (0.2 ± 0.4%)
# Tiempo desbalanceo: 92.7 ± 30.9 (4.8 ± 1.6%)
# Recompensa: -22.3 ± 7.3

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\varepsilon = 0,5$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.1,
    'alpha_step': 1,
    'alpha_end':  0.1,

    'eps_init': 0.5,
    'eps_step': 1,
    'eps_end':  0.5
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 15.7 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 7.1 ± 3.6 (3.7 ± 1.8%)
# # Prolongados: 0.3 ± 0.6 (0.2 ± 0.3%)
# Tiempo desbalanceo: 90.7 ± 29.7 (4.7 ± 1.5%)
# Recompensa: -19.4 ± 6.5
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 7.0 ± 3.5 (3.6 ± 1.8%)
# # Prolongados: 0.3 ± 0.7 (0.2 ± 0.4%)
# Tiempo desbalanceo: 91.0 ± 28.6 (4.7 ± 1.5%)
# Recompensa: -19.2 ± 6.1

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\varepsilon = 0,7$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.1,
    'alpha_step': 1,
    'alpha_end':  0.1,

    'eps_init': 0.7,
    'eps_step': 1,
    'eps_end':  0.7
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 15.0 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 6.9 ± 3.4 (3.6 ± 1.7%)
# # Prolongados: 0.3 ± 0.7 (0.2 ± 0.4%)
# Tiempo desbalanceo: 91.1 ± 30.0 (4.7 ± 1.6%)
# Recompensa: -17.6 ± 6.6
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 7.4 ± 3.7 (3.8 ± 1.8%)
# # Prolongados: 0.3 ± 0.7 (0.2 ± 0.4%)
# Tiempo desbalanceo: 94.2 ± 30.6 (4.9 ± 1.6%)
# Recompensa: -17.7 ± 6.6

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\varepsilon = 0,9$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.1,
    'alpha_step': 1,
    'alpha_end':  0.1,

    'eps_init': 0.9,
    'eps_step': 1,
    'eps_end':  0.9
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 15.1 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 9.9 ± 4.6 (5.2 ± 2.3%)
# # Prolongados: 0.4 ± 0.7 (0.2 ± 0.4%)
# Tiempo desbalanceo: 123.3 ± 38.8 (6.4 ± 2.0%)
# Recompensa: -17.6 ± 6.6
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 9.3 ± 4.3 (4.8 ± 2.2%)
# # Prolongados: 0.5 ± 0.8 (0.2 ± 0.4%)
# Tiempo desbalanceo: 119.0 ± 39.2 (6.2 ± 2.0%)
# Recompensa: -17.4 ± 6.6

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\varepsilon = 0,9 \to 0,1$ (programa de tasa de exploración)

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.1,
    'alpha_step': 1,
    'alpha_end':  0.1,

    'eps_init': 0.9,
    'eps_step': 0.99995,
    'eps_end':  0.1
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 16.7 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 8.6 ± 4.2 (4.5 ± 2.1%)
# # Prolongados: 0.9 ± 1.3 (0.5 ± 0.7%)
# Tiempo desbalanceo: 111.7 ± 38.7 (5.8 ± 2.0%)
# Recompensa: -30.0 ± 12.0
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 9.1 ± 4.4 (4.7 ± 2.2%)
# # Prolongados: 0.5 ± 0.9 (0.3 ± 0.5%)
# Tiempo desbalanceo: 115.7 ± 38.9 (6.0 ± 2.0%)
# Recompensa: -22.7 ± 8.9

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\alpha = 0,01$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.01,
    'alpha_step': 1,
    'alpha_end':  0.01,

    'eps_init': 0.7,
    'eps_step': 1,
    'eps_end':  0.7
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 14.8 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 16.6 ± 6.8 (8.6 ± 3.4%)
# # Prolongados: 2.1 ± 2.1 (1.2 ± 1.2%)
# Tiempo desbalanceo: 219.6 ± 70.1 (11.4 ± 3.6%)
# Recompensa: -21.5 ± 8.3
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 16.5 ± 6.9 (8.6 ± 3.5%)
# # Prolongados: 2.1 ± 2.1 (1.2 ± 1.2%)
# Tiempo desbalanceo: 217.0 ± 72.3 (11.3 ± 3.8%)
# Recompensa: -21.3 ± 8.3

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\alpha = 0,3$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.3,
    'alpha_step': 1,
    'alpha_end':  0.3,

    'eps_init': 0.7,
    'eps_step': 1,
    'eps_end':  0.7
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 14.8 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 6.3 ± 3.2 (3.3 ± 1.6%)
# # Prolongados: 0.2 ± 0.5 (0.1 ± 0.3%)
# Tiempo desbalanceo: 79.0 ± 26.1 (4.1 ± 1.4%)
# Recompensa: -22.5 ± 6.6
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 6.0 ± 3.4 (3.1 ± 1.7%)
# # Prolongados: 0.3 ± 0.7 (0.2 ± 0.4%)
# Tiempo desbalanceo: 79.2 ± 26.8 (4.1 ± 1.4%)
# Recompensa: -19.9 ± 6.9

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\alpha = 0,5$

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.5,
    'alpha_step': 1,
    'alpha_end':  0.5,

    'eps_init': 0.7,
    'eps_step': 1,
    'eps_end':  0.7
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 14.9 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 6.4 ± 3.3 (3.3 ± 1.7%)
# # Prolongados: 0.3 ± 0.7 (0.2 ± 0.4%)
# Tiempo desbalanceo: 80.9 ± 26.8 (4.2 ± 1.4%)
# Recompensa: -29.1 ± 6.6
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 6.2 ± 3.4 (3.2 ± 1.7%)
# # Prolongados: 0.4 ± 0.8 (0.2 ± 0.4%)
# Tiempo desbalanceo: 81.0 ± 29.7 (4.2 ± 1.5%)
# Recompensa: -25.8 ± 11.1

# %%
train.train_test_plot(metricas_train_test['rewards'])

# %% [markdown]
# ### Entrenar agente con $\alpha = 0,1 \to 0,01$ (programa de tasa de aprendizaje)

# %%
TRAIN_PARAMS = {
    'alpha_init': 0.1,
    'alpha_step': 0.99995,
    'alpha_end':  0.01,

    'eps_init': 0.7,
    'eps_step': 1,
    'eps_end':  0.7
}

random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Q-Learning ===")
agente_Q = agentes.QLearningAgent(action_size=env.action_space.n, alpha=TRAIN_PARAMS['alpha_init'], epsilon=TRAIN_PARAMS['eps_init'])
_, metricas_train_test, counters_train_test, best_qtable = train.train_test(env, agente_Q, params=TRAIN_PARAMS, N=10**5, keep_best=True, verbose=False)

# Testear la ultima Q-table
print("\nUltima Q table")
_, metricas_test, counters_test, _ = train.test(env, agente_Q.q_table, N=10**3)

# Testear la mejor Q-table
print("\nMejor Q table")
_, metricas_test, counters_test, _ = train.test(env, best_qtable, N=10**3)
# Out:
# === Agente Q-Learning ===
# Entrenamiento finalizado en 14.2 minutos.
#
# Ultima Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 13.9 ± 5.9 (7.2 ± 3.0%)
# # Prolongados: 0.7 ± 1.0 (0.4 ± 0.6%)
# Tiempo desbalanceo: 175.3 ± 55.9 (9.1 ± 2.9%)
# Recompensa: -18.6 ± 7.3
#
# Mejor Q table
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 14.8 ± 6.0 (7.7 ± 3.0%)
# # Prolongados: 0.8 ± 1.0 (0.5 ± 0.6%)
# Tiempo desbalanceo: 186.5 ± 55.3 (9.7 ± 2.9%)
# Recompensa: -19.7 ± 7.4

# %% [markdown]
# ### Evaluar agentes de referencia

# %%
random.seed(10)    # Aleatoriedad del agente
np.random.seed(10) # Aleatoriedad del entorno

env = entorno.Entorno(TAMANOS, COSTOS, TIEMPOS, PROBS)

print("=== Agente Nulo ===")
agente_N = agentes.NullAgent()
_, _, _, _ = train.train(env, agente_N, params=TRAIN_PARAMS, N=10**3)

print("\n=== Agente Aleatorio ===")
agente_R = agentes.RandomAgent(action_size=env.action_space.n)
_, _, _, _ = train.train(env, agente_R, params=TRAIN_PARAMS, N=10**3)

print("\n=== Agente Heurístico ===")
agente_H = agentes.HeuristicAgent(action_size=env.action_space.n)
_, _, _, _ = train.train(env, agente_H, params=TRAIN_PARAMS, N=10**3)
# Out:
# === Agente Nulo ===
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 18.3 ± 7.4 (9.5 ± 3.8%)
# # Prolongados: 5.3 ± 4.3 (3.1 ± 2.6%)
# Tiempo desbalanceo: 268.2 ± 92.9 (14.0 ± 4.8%)
# Recompensa: -23.6 ± 9.5
#
# === Agente Aleatorio ===
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 24.5 ± 6.3 (12.7 ± 3.1%)
# # Prolongados: 12.7 ± 6.1 (7.6 ± 3.9%)
# Tiempo desbalanceo: 335.8 ± 65.9 (17.5 ± 3.4%)
# Recompensa: -357.0 ± 72.4
#
# === Agente Heurístico ===
# Entrenamiento finalizado en 0.1 minutos.
# # Insatisfechos: 6.4 ± 3.6 (3.3 ± 1.8%)
# # Prolongados: 0.0 ± 0.0 (0.0 ± 0.0%)
# Tiempo desbalanceo: 75.2 ± 29.5 (3.9 ± 1.5%)
# Recompensa: -16.6 ± 4.7
